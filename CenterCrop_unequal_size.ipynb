# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
import numpy as np
import cv2

from scipy import ndimage, misc
import os, glob
import sys
import skimage
from skimage import feature, data, io

from scipy.misc import imread, imsave
from PIL import Image
import random

# %%
def get_file_name_dir(rootDir, ext):
 
    # Return file names with certain extension

    return glob.glob1(rootDir, "*." + ext)

def center_crop(img, h=470, w=470):
    """center crop a single image with cropsize x, y"""
    oh, ow, _ = img.shape
    dw = ow - w
    dh = oh - h
    startx = np.round(dw / 2).astype(int)
    starty = np.round(dh / 2).astype(int)
    return img[starty:starty + h, startx:startx + w, :]

# %%
input_path = 'data/CVC-ColonDB/images/'
input_extension = 'tiff'
inputs_files = sorted(get_file_name_dir(input_path, input_extension))

cont = 1
for file_name in inputs_files:
    print('Preprocessing: ' + file_name + ': ' + str(cont))
    cont += 1
    img = input_path + file_name
    im_in = cv2.imread(img)
    image = center_crop(im_in)

    cv2.imwrite(input_path + file_name , image)
# Out:
# Preprocessing: 1.tiff: 1
# Preprocessing: 10.tiff: 2
# Preprocessing: 100.tiff: 3
# Preprocessing: 101.tiff: 4
# Preprocessing: 102.tiff: 5
# Preprocessing: 103.tiff: 6
# Preprocessing: 104.tiff: 7
# Preprocessing: 105.tiff: 8
# Preprocessing: 106.tiff: 9
# Preprocessing: 107.tiff: 10
# Preprocessing: 108.tiff: 11
# Preprocessing: 109.tiff: 12
# Preprocessing: 11.tiff: 13
# Preprocessing: 110.tiff: 14
# Preprocessing: 111.tiff: 15
# Preprocessing: 112.tiff: 16
# Preprocessing: 113.tiff: 17
# Preprocessing: 114.tiff: 18
# Preprocessing: 115.tiff: 19
# Preprocessing: 116.tiff: 20
# Preprocessing: 117.tiff: 21
# Preprocessing: 118.tiff: 22
# Preprocessing: 119.tiff: 23
# Preprocessing: 12.tiff: 24
# Preprocessing: 120.tiff: 25
# Preprocessing: 121.tiff: 26
# Preprocessing: 122.tiff: 27
# Preprocessing: 123.tiff: 28
# Preprocessing: 124.tiff: 29
# Preprocessing: 125.tiff: 30
# Preprocessing: 126.tiff: 31
# Preprocessing: 127.tiff: 32
# Preprocessing: 128.tiff: 33
# Preprocessing: 129.tiff: 34
# Preprocessing: 13.tiff: 35
# Preprocessing: 130.tiff: 36
# Preprocessing: 131.tiff: 37
# Preprocessing: 132.tiff: 38
# Preprocessing: 133.tiff: 39
# Preprocessing: 134.tiff: 40
# Preprocessing: 135.tiff: 41
# Preprocessing: 136.tiff: 42
# Preprocessing: 137.tiff: 43
# Preprocessing: 138.tiff: 44
# Preprocessing: 139.tiff: 45
# Preprocessing: 14.tiff: 46
# Preprocessing: 140.tiff: 47
# Preprocessing: 141.tiff: 48
# Preprocessing: 142.tiff: 49
# Preprocessing: 143.tiff: 50
# Preprocessing: 144.tiff: 51
# Preprocessing: 145.tiff: 52
# Preprocessing: 146.tiff: 53
# Preprocessing: 147.tiff: 54
# Preprocessing: 148.tiff: 55
# Preprocessing: 149.tiff: 56
# Preprocessing: 15.tiff: 57
# Preprocessing: 150.tiff: 58
# Preprocessing: 151.tiff: 59
# Preprocessing: 152.tiff: 60
# Preprocessing: 153.tiff: 61
# Preprocessing: 154.tiff: 62
# Preprocessing: 155.tiff: 63
# Preprocessing: 156.tiff: 64
# Preprocessing: 157.tiff: 65
# Preprocessing: 158.tiff: 66
# Preprocessing: 159.tiff: 67
# Preprocessing: 16.tiff: 68
# Preprocessing: 160.tiff: 69
# Preprocessing: 161.tiff: 70
# Preprocessing: 162.tiff: 71
# Preprocessing: 163.tiff: 72
# Preprocessing: 164.tiff: 73
# Preprocessing: 165.tiff: 74
# Preprocessing: 166.tiff: 75
# Preprocessing: 167.tiff: 76
# Preprocessing: 168.tiff: 77
# Preprocessing: 169.tiff: 78
# Preprocessing: 17.tiff: 79
# Preprocessing: 170.tiff: 80
# Preprocessing: 171.tiff: 81
# Preprocessing: 172.tiff: 82
# Preprocessing: 173.tiff: 83
# Preprocessing: 174.tiff: 84
# Preprocessing: 175.tiff: 85
# Preprocessing: 176.tiff: 86
# Preprocessing: 177.tiff: 87
# Preprocessing: 178.tiff: 88
# Preprocessing: 179.tiff: 89
# Preprocessing: 18.tiff: 90
# Preprocessing: 180.tiff: 91
# Preprocessing: 181.tiff: 92
# Preprocessing: 182.tiff: 93
# Preprocessing: 183.tiff: 94
# Preprocessing: 184.tiff: 95
# Preprocessing: 185.tiff: 96
# Preprocessing: 186.tiff: 97
# Preprocessing: 187.tiff: 98
# Preprocessing: 188.tiff: 99
# Preprocessing: 189.tiff: 100
# Preprocessing: 19.tiff: 101
# Preprocessing: 190.tiff: 102
# Preprocessing: 191.tiff: 103
# Preprocessing: 192.tiff: 104
# Preprocessing: 193.tiff: 105
# Preprocessing: 194.tiff: 106
# Preprocessing: 195.tiff: 107
# Preprocessing: 196.tiff: 108
# Preprocessing: 197.tiff: 109
# Preprocessing: 198.tiff: 110
# Preprocessing: 199.tiff: 111
# Preprocessing: 2.tiff: 112
# Preprocessing: 20.tiff: 113
# Preprocessing: 200.tiff: 114
# Preprocessing: 201.tiff: 115
# Preprocessing: 202.tiff: 116
# Preprocessing: 203.tiff: 117
# Preprocessing: 204.tiff: 118
# Preprocessing: 205.tiff: 119
# Preprocessing: 206.tiff: 120
# Preprocessing: 207.tiff: 121
# Preprocessing: 208.tiff: 122
# Preprocessing: 209.tiff: 123
# Preprocessing: 21.tiff: 124
# Preprocessing: 210.tiff: 125
# Preprocessing: 211.tiff: 126
# Preprocessing: 212.tiff: 127
# Preprocessing: 213.tiff: 128
# Preprocessing: 214.tiff: 129
# Preprocessing: 215.tiff: 130
# Preprocessing: 216.tiff: 131
# Preprocessing: 217.tiff: 132
# Preprocessing: 218.tiff: 133
# Preprocessing: 219.tiff: 134
# Preprocessing: 22.tiff: 135
# Preprocessing: 220.tiff: 136
# Preprocessing: 221.tiff: 137
# Preprocessing: 222.tiff: 138
# Preprocessing: 223.tiff: 139
# Preprocessing: 224.tiff: 140
# Preprocessing: 225.tiff: 141
# Preprocessing: 226.tiff: 142
# Preprocessing: 227.tiff: 143
# Preprocessing: 228.tiff: 144
# Preprocessing: 229.tiff: 145
# Preprocessing: 23.tiff: 146
# Preprocessing: 230.tiff: 147
# Preprocessing: 231.tiff: 148
# Preprocessing: 232.tiff: 149
# Preprocessing: 233.tiff: 150
# Preprocessing: 234.tiff: 151
# Preprocessing: 235.tiff: 152
# Preprocessing: 236.tiff: 153
# Preprocessing: 237.tiff: 154
# Preprocessing: 238.tiff: 155
# Preprocessing: 239.tiff: 156
# Preprocessing: 24.tiff: 157
# Preprocessing: 240.tiff: 158
# Preprocessing: 241.tiff: 159
# Preprocessing: 242.tiff: 160
# Preprocessing: 243.tiff: 161
# Preprocessing: 244.tiff: 162
# Preprocessing: 245.tiff: 163
# Preprocessing: 246.tiff: 164
# Preprocessing: 247.tiff: 165
# Preprocessing: 248.tiff: 166
# Preprocessing: 249.tiff: 167
# Preprocessing: 25.tiff: 168
# Preprocessing: 250.tiff: 169
# Preprocessing: 251.tiff: 170
# Preprocessing: 252.tiff: 171
# Preprocessing: 253.tiff: 172
# Preprocessing: 254.tiff: 173
# Preprocessing: 255.tiff: 174
# Preprocessing: 256.tiff: 175
# Preprocessing: 257.tiff: 176
# Preprocessing: 258.tiff: 177
# Preprocessing: 259.tiff: 178
# Preprocessing: 26.tiff: 179
# Preprocessing: 260.tiff: 180
# Preprocessing: 261.tiff: 181
# Preprocessing: 262.tiff: 182
# Preprocessing: 263.tiff: 183
# Preprocessing: 264.tiff: 184
# Preprocessing: 265.tiff: 185
# Preprocessing: 266.tiff: 186
# Preprocessing: 267.tiff: 187
# Preprocessing: 268.tiff: 188
# Preprocessing: 269.tiff: 189
# Preprocessing: 27.tiff: 190
# Preprocessing: 270.tiff: 191
# Preprocessing: 271.tiff: 192
# Preprocessing: 272.tiff: 193
# Preprocessing: 273.tiff: 194
# Preprocessing: 274.tiff: 195
# Preprocessing: 275.tiff: 196
# Preprocessing: 276.tiff: 197
# Preprocessing: 277.tiff: 198
# Preprocessing: 278.tiff: 199
# Preprocessing: 279.tiff: 200
# Preprocessing: 28.tiff: 201
# Preprocessing: 280.tiff: 202
# Preprocessing: 281.tiff: 203
# Preprocessing: 282.tiff: 204
# Preprocessing: 283.tiff: 205
# Preprocessing: 284.tiff: 206
# Preprocessing: 285.tiff: 207
# Preprocessing: 286.tiff: 208
# Preprocessing: 287.tiff: 209
# Preprocessing: 288.tiff: 210
# Preprocessing: 289.tiff: 211
# Preprocessing: 29.tiff: 212
# Preprocessing: 290.tiff: 213
# Preprocessing: 291.tiff: 214
# Preprocessing: 292.tiff: 215
# Preprocessing: 293.tiff: 216
# Preprocessing: 294.tiff: 217
# Preprocessing: 295.tiff: 218
# Preprocessing: 296.tiff: 219
# Preprocessing: 297.tiff: 220
# Preprocessing: 298.tiff: 221
# Preprocessing: 299.tiff: 222
# Preprocessing: 3.tiff: 223
# Preprocessing: 30.tiff: 224
# Preprocessing: 300.tiff: 225
# Preprocessing: 301.tiff: 226
# Preprocessing: 302.tiff: 227
# Preprocessing: 303.tiff: 228
# Preprocessing: 304.tiff: 229
# Preprocessing: 305.tiff: 230
# Preprocessing: 306.tiff: 231
# Preprocessing: 307.tiff: 232
# Preprocessing: 308.tiff: 233
# Preprocessing: 309.tiff: 234
# Preprocessing: 31.tiff: 235
# Preprocessing: 310.tiff: 236
# Preprocessing: 311.tiff: 237
# Preprocessing: 312.tiff: 238
# Preprocessing: 313.tiff: 239
# Preprocessing: 314.tiff: 240
# Preprocessing: 315.tiff: 241
# Preprocessing: 316.tiff: 242
# Preprocessing: 317.tiff: 243
# Preprocessing: 318.tiff: 244
# Preprocessing: 319.tiff: 245
# Preprocessing: 32.tiff: 246
# Preprocessing: 320.tiff: 247
# Preprocessing: 321.tiff: 248
# Preprocessing: 322.tiff: 249
# Preprocessing: 323.tiff: 250
# Preprocessing: 324.tiff: 251
# Preprocessing: 325.tiff: 252
# Preprocessing: 326.tiff: 253
# Preprocessing: 327.tiff: 254
# Preprocessing: 328.tiff: 255
# Preprocessing: 329.tiff: 256
# Preprocessing: 33.tiff: 257
# Preprocessing: 330.tiff: 258
# Preprocessing: 331.tiff: 259
# Preprocessing: 332.tiff: 260
# Preprocessing: 333.tiff: 261
# Preprocessing: 334.tiff: 262
# Preprocessing: 335.tiff: 263
# Preprocessing: 336.tiff: 264
# Preprocessing: 337.tiff: 265
# Preprocessing: 338.tiff: 266
# Preprocessing: 339.tiff: 267
# Preprocessing: 34.tiff: 268
# Preprocessing: 340.tiff: 269
# Preprocessing: 341.tiff: 270
# Preprocessing: 342.tiff: 271
# Preprocessing: 343.tiff: 272
# Preprocessing: 344.tiff: 273
# Preprocessing: 345.tiff: 274
# Preprocessing: 346.tiff: 275
# Preprocessing: 347.tiff: 276
# Preprocessing: 348.tiff: 277
# Preprocessing: 349.tiff: 278
# Preprocessing: 35.tiff: 279
# Preprocessing: 350.tiff: 280
# Preprocessing: 351.tiff: 281
# Preprocessing: 352.tiff: 282
# Preprocessing: 353.tiff: 283
# Preprocessing: 354.tiff: 284
# Preprocessing: 355.tiff: 285
# Preprocessing: 356.tiff: 286
# Preprocessing: 357.tiff: 287
# Preprocessing: 358.tiff: 288
# Preprocessing: 359.tiff: 289
# Preprocessing: 36.tiff: 290
# Preprocessing: 360.tiff: 291
# Preprocessing: 361.tiff: 292
# Preprocessing: 362.tiff: 293
# Preprocessing: 363.tiff: 294
# Preprocessing: 364.tiff: 295
# Preprocessing: 365.tiff: 296
# Preprocessing: 366.tiff: 297
# Preprocessing: 367.tiff: 298
# Preprocessing: 368.tiff: 299
# Preprocessing: 369.tiff: 300
# Preprocessing: 37.tiff: 301
# Preprocessing: 370.tiff: 302
# Preprocessing: 371.tiff: 303
# Preprocessing: 372.tiff: 304
# Preprocessing: 373.tiff: 305
# Preprocessing: 374.tiff: 306
# Preprocessing: 375.tiff: 307
# Preprocessing: 376.tiff: 308
# Preprocessing: 377.tiff: 309
# Preprocessing: 378.tiff: 310
# Preprocessing: 379.tiff: 311
