# %% [markdown]
# #### Source: https://www.kaggle.com/kmader/detect-retina-damage-from-oct-images-hr

# %% [markdown]
# ___

# %%
import os
import numpy as np
import cv2
import pandas as pd
import seaborn as sns
import skimage.transform
from tqdm import tqdm, tqdm_notebook


from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
imageSize=224

train_dir = "data/train/"
test_dir =  "data/test/"

# %%
# Class folder inside train folder:  ['DME', 'CNV', 'NORMAL', 'DRUSEN']
# We have fout classes

def get_data(folder):
    """
    Load the data and labels from the given folder.
    """
    X = []
    y = []
    for folderName in os.listdir(folder):
        if not folderName.startswith('.'):
            if folderName in ['NORMAL']:
                label = 0
            elif folderName in ['CNV']:
                label = 1
            elif folderName in ['DME']:
                label = 2
            elif folderName in ['DRUSEN']:
                label = 3
            else:
                label = 4
            for image_filename in tqdm_notebook(os.listdir(folder + folderName)):
                img_file = cv2.imread(folder + folderName + '/' + image_filename)
                if img_file is not None:
                    img_file = skimage.transform.resize(img_file, (imageSize, imageSize, 3))
                    img_arr = np.asarray(img_file)
                    X.append(img_arr)
                    y.append(label)
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
#X_train, y_train = get_data(train_dir)
X_test, y_test= get_data(test_dir)


X_train, X_test, y_train, y_test = train_test_split(X_test, y_test, test_size=0.2)
# Out:
# ...
# /home/sara/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/sara/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/sara/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/sara/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# ...

# %%
# Encode labels to hot vectors

y_trainHot = to_categorical(y_train, num_classes = 4)
y_testHot = to_categorical(y_test, num_classes = 4)

# %%
X_train.shape
# Out:
# (774, 224, 224, 3)

# %%
y_train.shape
# Out:
# (774,)

# %%
len(X_train)
# Out:
# 774

# %%
X_train.dtype
# Out:
# dtype('float64')

# %%
X_train.ndim
# Out:
# 4

# %%
plt.imshow(X_train[0])
plt.show()

# %%
# X_train[0]

# %%
map_characters = {0: 'Normal', 1: 'CNV', 2: 'DME', 3: 'DRUSEN'}
dict_characters=map_characters

df = pd.DataFrame()
df["labels"]=y_train
lab = df['labels']
dist = lab.value_counts()
sns.countplot(lab)
print(dict_characters)
# Out:
# {0: 'Normal', 1: 'CNV', 2: 'DME', 3: 'DRUSEN'}
